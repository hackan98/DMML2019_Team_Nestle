# %% [markdown]
# # Data mining, Project group Nestlé

# %% [markdown]
# ## Happiness Report

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
WHR = pd.read_excel("https://s3.amazonaws.com/happiness-report/2019/Chapter2OnlineData.xls")

# %%
WHR.head()
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  ...  \
# ...

# %%
WHR.columns
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality', 'Standard deviation of ladder by country-year',
#        'Standard deviation/Mean of ladder by country-year',
#        'GINI index (World Bank estimate)',
#        'GINI index (World Bank estimate), average 2000-16',
#        'gini of household income reported in Gallup, by wp5-year',
#        'Most people can be trusted, Gallup',
#        'Most people can be trusted, WVS round 1981-1984',
#        'Most people can be trusted, WVS round 1989-1993',
#        'Most people can be trusted, WVS round 1994-1998',
#        'Most people can be trusted, WVS round 1999-2004',
#        'Most people can be trusted, WVS round 2005-2009',
# ...

# %%
to_drop = [ 'Social support','Freedom to make life choices', 'Generosity',
       'Perceptions of corruption', 'Positive affect', 'Negative affect',
       'Confidence in national government', 'Democratic Quality',
       'Delivery Quality', 'Standard deviation of ladder by country-year',
       'Standard deviation/Mean of ladder by country-year',
       'GINI index (World Bank estimate)',
       'GINI index (World Bank estimate), average 2000-16',
       'gini of household income reported in Gallup, by wp5-year',
       'Most people can be trusted, Gallup',
       'Most people can be trusted, WVS round 1981-1984',
       'Most people can be trusted, WVS round 1989-1993',
       'Most people can be trusted, WVS round 1994-1998',
       'Most people can be trusted, WVS round 1999-2004',
       'Most people can be trusted, WVS round 2005-2009',
       'Most people can be trusted, WVS round 2010-2014',]

WHR.drop(to_drop, inplace=True, axis=1)

# %%
WHR
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  \
# 0     Afghanistan  2008     3.723590            7.168690
# 1     Afghanistan  2009     4.401778            7.333790
# 2     Afghanistan  2010     4.758381            7.386629
# 3     Afghanistan  2011     3.831719            7.415019
# 4     Afghanistan  2012     3.782938            7.517126
# 5     Afghanistan  2013     3.572100            7.522238
# 6     Afghanistan  2014     3.130896            7.516955
# 7     Afghanistan  2015     3.982855            7.500539
# 8     Afghanistan  2016     4.220169            7.497038
# 9     Afghanistan  2017     2.661718            7.497755
# 10    Afghanistan  2018     2.694303            7.494588
# 11        Albania  2007     4.634252            9.077331
# 12        Albania  2009     5.485470            9.161638
# 13        Albania  2010     5.268937            9.203032
# 14        Albania  2011     5.867422            9.230904
# ...

# %%
WHR.dropna(inplace=True)

# %%
WHR
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  \
# 0     Afghanistan  2008     3.723590            7.168690
# 1     Afghanistan  2009     4.401778            7.333790
# 2     Afghanistan  2010     4.758381            7.386629
# 3     Afghanistan  2011     3.831719            7.415019
# 4     Afghanistan  2012     3.782938            7.517126
# 5     Afghanistan  2013     3.572100            7.522238
# 6     Afghanistan  2014     3.130896            7.516955
# 7     Afghanistan  2015     3.982855            7.500539
# 8     Afghanistan  2016     4.220169            7.497038
# 9     Afghanistan  2017     2.661718            7.497755
# 10    Afghanistan  2018     2.694303            7.494588
# 11        Albania  2007     4.634252            9.077331
# 12        Albania  2009     5.485470            9.161638
# 13        Albania  2010     5.268937            9.203032
# 14        Albania  2011     5.867422            9.230904
# ...

# %% [markdown]
# ### Features correlations with target value Life Ladder (happinness score)

# %%
WHR.corr(method="pearson", min_periods=20)["Life Ladder"].sort_values(ascending=False)
# Out:
# Life Ladder                                                 1.000000
# Log GDP per capita                                          0.779064
# Healthy life expectancy at birth                            0.736797
# Delivery Quality                                            0.707940
# Social support                                              0.702461
# Democratic Quality                                          0.614572
# Most people can be trusted, WVS round 1981-1984             0.554803
# Positive affect                                             0.543377
# Freedom to make life choices                                0.520988
# Most people can be trusted, WVS round 2005-2009             0.477312
# Most people can be trusted, WVS round 1994-1998             0.475632
# Most people can be trusted, WVS round 2010-2014             0.348629
# Most people can be trusted, WVS round 1999-2004             0.266804
# Generosity                                                  0.197423
# ...

# %%
WHR.corr(method="pearson", min_periods=20)["Life Ladder"].abs().sort_values(ascending=False)
# Out:
# Life Ladder                                                 1.000000
# Log GDP per capita                                          0.779064
# Standard deviation/Mean of ladder by country-year           0.753971
# Healthy life expectancy at birth                            0.736797
# Delivery Quality                                            0.707940
# Social support                                              0.702461
# Democratic Quality                                          0.614572
# Most people can be trusted, WVS round 1981-1984             0.554803
# Positive affect                                             0.543377
# Freedom to make life choices                                0.520988
# Most people can be trusted, WVS round 2005-2009             0.477312
# Most people can be trusted, WVS round 1994-1998             0.475632
# Perceptions of corruption                                   0.420750
# Most people can be trusted, WVS round 2010-2014             0.348629
# ...

# %% [markdown]
# ### Unemployement rate data set

# %%
TauxChomage = pd.read_csv("https://raw.githubusercontent.com/hackan98/DMML2019_Team_Nestle/master/data/tauxchomage.csv")

# %%
TauxChomage
# Out:
#       LOCATION INDICATOR SUBJECT MEASURE FREQUENCY     TIME      Value  \
# 0          AUS     UNEMP     MEN   PC_LF         A     1979   5.162579
# 1          AUS     UNEMP     MEN   PC_LF         A     1980   5.068766
# 2          AUS     UNEMP     MEN   PC_LF         A     1981   4.808415
# 3          AUS     UNEMP     MEN   PC_LF         A     1982   6.345981
# 4          AUS     UNEMP     MEN   PC_LF         A     1983   9.716337
# 5          AUS     UNEMP     MEN   PC_LF         A     1984   8.686903
# 6          AUS     UNEMP     MEN   PC_LF         A     1985   7.943595
# 7          AUS     UNEMP     MEN   PC_LF         A     1986   7.669734
# 8          AUS     UNEMP     MEN   PC_LF         A     1987   7.761060
# 9          AUS     UNEMP     MEN   PC_LF         A     1988   6.768215
# 10         AUS     UNEMP     MEN   PC_LF         A     1989   5.711262
# 11         AUS     UNEMP     MEN   PC_LF         A     1990   6.732783
# ...

# %% [markdown]
# ### Poverty rate data set

# %%
TauxPauvrete = pd.read_csv("https://raw.githubusercontent.com/hackan98/DMML2019_Team_Nestle/master/data/taux_pauvrete.csv")

# %%
TauxPauvrete.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value Flag Codes
# 0      AUS   POVERTY     TOT      RT         A  2012  0.140        NaN
# 1      AUS   POVERTY     TOT      RT         A  2014  0.128        NaN
# 2      AUS   POVERTY     TOT      RT         A  2016  0.121        NaN
# 3      AUT   POVERTY     TOT      RT         A  2007  0.097        NaN
# 4      AUT   POVERTY     TOT      RT         A  2008  0.092        NaN

# %% [markdown]
# ### Child mortality rate data set

# %%
TauxMortaliteInfantile = pd.read_csv("https://raw.githubusercontent.com/hackan98/DMML2019_Team_Nestle/master/data/taux_mortalite_infantile.csv")

# %%
TauxMortaliteInfantile.head()
# Out:
#   LOCATION        INDICATOR SUBJECT          MEASURE FREQUENCY  TIME  Value  \
# 0      AUS  INFANTMORTALITY     TOT  DEATH_1000BIRTH         A  2006    4.7
# 1      AUS  INFANTMORTALITY     TOT  DEATH_1000BIRTH         A  2007    4.1
# 2      AUS  INFANTMORTALITY     TOT  DEATH_1000BIRTH         A  2008    4.1
# 3      AUS  INFANTMORTALITY     TOT  DEATH_1000BIRTH         A  2009    4.2
# 4      AUS  INFANTMORTALITY     TOT  DEATH_1000BIRTH         A  2010    4.1
#
#   Flag Codes
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %% [markdown]
# ### Suicide rate data set

# %%
TauxSuicide = pd.read_csv("https://raw.githubusercontent.com/hackan98/DMML2019_Team_Nestle/master/data/tauxsuicide.csv")

# %%
TauxSuicide
# Out:
#     LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value Flag Codes
# 0        AUS   SUICIDE     TOT  100000PER         A  2006   10.5        NaN
# 1        AUS   SUICIDE     TOT  100000PER         A  2007   10.6        NaN
# 2        AUS   SUICIDE     TOT  100000PER         A  2008   10.9        NaN
# 3        AUS   SUICIDE     TOT  100000PER         A  2009   10.7        NaN
# 4        AUS   SUICIDE     TOT  100000PER         A  2010   10.9        NaN
# 5        AUS   SUICIDE     TOT  100000PER         A  2011   10.7        NaN
# 6        AUS   SUICIDE     TOT  100000PER         A  2012   11.4        NaN
# 7        AUS   SUICIDE     TOT  100000PER         A  2013   11.3        NaN
# 8        AUS   SUICIDE     TOT  100000PER         A  2014   12.5        NaN
# 9        AUS   SUICIDE     TOT  100000PER         A  2015   12.9        NaN
# 10       AUS   SUICIDE     TOT  100000PER         A  2016   11.9        NaN
# ...

# %%
TauxSuicide.columns
# Out:
# Index(['LOCATION', 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'TIME',
#        'Value', 'Flag Codes'],
#       dtype='object')

# %%
to_drop = [ 'INDICATOR', 'SUBJECT', 'MEASURE', 'FREQUENCY', 'Flag Codes']

TauxSuicide.drop(to_drop, inplace=True, axis=1)

# %%
TauxSuicide.head()
# Out:
#   LOCATION  TIME  Value
# 0      AUS  2006   10.5
# 1      AUS  2007   10.6
# 2      AUS  2008   10.9
# 3      AUS  2009   10.7
# 4      AUS  2010   10.9

# %%
TauxSuicide.dropna()
# Out:
#     LOCATION  TIME  Value
# 0        AUS  2006   10.5
# 1        AUS  2007   10.6
# 2        AUS  2008   10.9
# 3        AUS  2009   10.7
# 4        AUS  2010   10.9
# 5        AUS  2011   10.7
# 6        AUS  2012   11.4
# 7        AUS  2013   11.3
# 8        AUS  2014   12.5
# 9        AUS  2015   12.9
# 10       AUS  2016   11.9
# 11       AUT  2006   14.7
# 12       AUT  2007   14.6
# 13       AUT  2008   14.1
# 14       AUT  2009   14.1
# 15       AUT  2010   13.9
# 16       AUT  2011   14.1
# 17       AUT  2012   13.7
# 18       AUT  2013   13.6
# 19       AUT  2014   13.9
# 20       AUT  2015   12.9
# 21       AUT  2016   12.2
# 22       AUT  2017   12.4
# 23       BEL  2006   17.7
# 24       BEL  2007   16.7
# 25       BEL  2008   17.9
# 26       BEL  2009   17.9
# 27       BEL  2010   17.8
# 28       BEL  2011   18.1
# 29       BEL  2012   17.4
# ..       ...   ...    ...
# 401      LVA  2007   19.9
# 402      LVA  2008   23.1
# 403      LVA  2009   23.1
# ...

# %%
countriesName={
'AUS':'Australia',
'AUT':'Austria',
'BEL':'Belgium',
'CAN':'Canada',
'CZE':'Czechia',
'DNK':'Denmark',
'FIN':'Finland',
'FR':'France',
'DEU':'Germany',
'GRC':'Greece',
'HUN':'Hungary',
'ISL':'Iceland',
'IRL':'Ireland',
'ITA':'Italy',
'KOR':'Korea',
'LUX':'Luxembourg',
'MEX':'Mexico',
'NLD':'Netherlands',
'NZL':'New Zealand',
'NOR':'Norway',
'POL':'Poland',
'PRT':'Puerto Rico',
'SVK':'Slovakia',
'ESP':'Spain',
'SWE':'Sweden',
'CHE':'Switzerland',
'TUR':'Turkey',
'GBR':'United Kingdom',
'USA':'United States',
'BRA':'Brasil',
'CHL':'Chile',
'EST':'Estonia',
'IDN':'Indonesia',
'ISR':'Israel',
'RUS':'Russia',
'SVN':'Slovenia',
'ZAF':'South Africa',
'COL':'Colombia',
'LVA':'Latvia',
'LTU':'Lithuania',
'CRI':'Costa Rica'    
}

# %%
TauxSuicide['COUNTRY'] = TauxSuicide['LOCATION'].map(countriesName)

# %%
TauxSuicide
# Out:
#     LOCATION  TIME  Value     COUNTRY
# 0        AUS  2006   10.5   Australia
# 1        AUS  2007   10.6   Australia
# 2        AUS  2008   10.9   Australia
# 3        AUS  2009   10.7   Australia
# 4        AUS  2010   10.9   Australia
# 5        AUS  2011   10.7   Australia
# 6        AUS  2012   11.4   Australia
# 7        AUS  2013   11.3   Australia
# 8        AUS  2014   12.5   Australia
# 9        AUS  2015   12.9   Australia
# 10       AUS  2016   11.9   Australia
# 11       AUT  2006   14.7     Austria
# 12       AUT  2007   14.6     Austria
# 13       AUT  2008   14.1     Austria
# 14       AUT  2009   14.1     Austria
# 15       AUT  2010   13.9     Austria
# 16       AUT  2011   14.1     Austria
# 17       AUT  2012   13.7     Austria
# 18       AUT  2013   13.6     Austria
# 19       AUT  2014   13.9     Austria
# 20       AUT  2015   12.9     Austria
# 21       AUT  2016   12.2     Austria
# 22       AUT  2017   12.4     Austria
# 23       BEL  2006   17.7     Belgium
# ...

# %%
TauxSuicide.COUNTRY.unique
# Out:
# <bound method Series.unique of 0      Australia
# 1      Australia
# 2      Australia
# 3      Australia
# 4      Australia
# 5      Australia
# 6      Australia
# 7      Australia
# 8      Australia
# 9      Australia
# 10     Australia
# 11       Austria
# 12       Austria
# 13       Austria
# 14       Austria
# 15       Austria
# 16       Austria
# 17       Austria
# 18       Austria
# 19       Austria
# 20       Austria
# 21       Austria
# 22       Austria
# 23       Belgium
# 24       Belgium
# 25       Belgium
# 26       Belgium
# 27       Belgium
# 28       Belgium
# 29       Belgium
#          ...
# 401       Latvia
# 402       Latvia
# 403       Latvia
# 404       Latvia
# 405       Latvia
# 406       Latvia
# 407       Latvia
# 408       Latvia
# 409       Latvia
# 410    Lithuania
# 411    Lithuania
# 412    Lithuania
# 413    Lithuania
# 414    Lithuania
# 415    Lithuania
# 416    Lithuania
# 417    Lithuania
# 418    Lithuania
# 419    Lithuania
# 420    Lithuania
# ...

# %%
TauxSuicide.LOCATION.unique
# Out:
# <bound method Series.unique of 0      AUS
# 1      AUS
# 2      AUS
# 3      AUS
# 4      AUS
# 5      AUS
# 6      AUS
# 7      AUS
# 8      AUS
# 9      AUS
# 10     AUS
# 11     AUT
# 12     AUT
# 13     AUT
# 14     AUT
# 15     AUT
# 16     AUT
# 17     AUT
# 18     AUT
# 19     AUT
# 20     AUT
# 21     AUT
# 22     AUT
# 23     BEL
# 24     BEL
# 25     BEL
# 26     BEL
# 27     BEL
# 28     BEL
# 29     BEL
#       ...
# 401    LVA
# 402    LVA
# 403    LVA
# 404    LVA
# 405    LVA
# 406    LVA
# 407    LVA
# 408    LVA
# 409    LVA
# 410    LTU
# 411    LTU
# 412    LTU
# 413    LTU
# 414    LTU
# 415    LTU
# 416    LTU
# 417    LTU
# 418    LTU
# 419    LTU
# 420    LTU
# 421    LTU
# 422    CRI
# 423    CRI
# 424    CRI
# 425    CRI
# 426    CRI
# 427    CRI
# 428    CRI
# 429    CRI
# 430    CRI
# Name: LOCATION, Length: 431, dtype: object>
